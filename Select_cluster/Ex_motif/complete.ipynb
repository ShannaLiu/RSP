# %% [markdown]
# **Complete graph**

# %%
sys.path.append('/Users/liushuhan/Documents/AL_GNN/Experiments/RSP/Sythentic_graph')
sys.path.append('../')
from Generator import *
import matplotlib.pyplot as plt
from util import *
from loss import *
from Estimator import *
from cluster import *

# %%
list_shapes = ['nx.complete_graph'] * 3
list_shapes_args = [[10]]*3
graph_type = 'nx.connected_watts_strogatz_graph'
graph_args = [3, 2, 0.4]
G, Gg, group_label, shape_label, shape_dist = synthetic_graph_generator(list_shapes, list_shapes_args, graph_type, graph_args, \
    plot=True, plot_color='group_label', savefig=False, root=None, figname=None)
L, D, Gamma = graph_to_mat(G)

# %% [markdown]
# # num_features=20, (< num_nodes=30), num_latent_features=8,

# %% [markdown]
# ## No noise

# %%
U, latent_features, node_features = sub_noisy_feature_generator(group_label, num_features=20, num_latent_features=8, std=0.0, standard_basis=False)

# %% [markdown]
# ### LR loss

# %%
l3s = np.float32([1,5,10,20,50,100,500,1000])
num3 = len(l3s)
num = num3
flag = 1
f = plt.figure(figsize=(10,4))
for i in range(num3):
    ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
    lr = LR_Estimator(l3=l3s[i], method='cp', solver='SCS')
    lr.fit(node_features, maxiter=1000)
    lr.heatplot(xticklabels=False, yticklabels=False, cbar=True)
    ax0.set_title('l3:'+str(int(np.round(l3s[i]))))
    flag = flag+1
del l3s
# Out:
# /Users/liushuhan/opt/anaconda3/lib/python3.9/site-packages/cvxpy/problems/problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %% [markdown]
# ### ss_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del sse

# %% [markdown]
# ### as_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# ### aa_EL_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# ## Noise std=0.5

# %%
U, latent_features, node_features = sub_noisy_feature_generator(group_label, num_features=20, num_latent_features=8, std=0.5, standard_basis=False)

# %% [markdown]
# ### LR loss

# %%
l3s = np.float32([1,5,10,20,50,100,500,1000])
num3 = len(l3s)
num = num3
flag = 1
f = plt.figure(figsize=(10,4))
for i in range(num3):
    ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
    lr = LR_Estimator(l3=l3s[i], method='cp', solver='SCS')
    lr.fit(node_features, maxiter=1000)
    lr.heatplot(xticklabels=False, yticklabels=False, cbar=True)
    ax0.set_title('l3:'+str(int(np.round(l3s[i]))))
    flag = flag+1
del l3s

# %% [markdown]
# ### ss_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del sse

# %% [markdown]
# ### as_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# ### aa_EL_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# ## Noise std=1

# %%
U, latent_features, node_features = sub_noisy_feature_generator(group_label, num_features=20, num_latent_features=8, std=1.0, standard_basis=False)

# %% [markdown]
# ### LR loss

# %%
l3s = np.float32([1,5,10,20,50,100,500,1000])
num3 = len(l3s)
num = num3
flag = 1
f = plt.figure(figsize=(10,4))
for i in range(num3):
    ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
    lr = LR_Estimator(l3=l3s[i], method='cp', solver='SCS')
    lr.fit(node_features, maxiter=1000)
    lr.heatplot(xticklabels=False, yticklabels=False, cbar=True)
    ax0.set_title('l3:'+str(int(np.round(l3s[i]))))
    flag = flag+1
del l3s

# %% [markdown]
# ### ss_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del sse

# %% [markdown]
# ### as_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# ### aa_EL_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# # num_features=40, (> num_nodes=30), num_latent_features=8,

# %% [markdown]
# ## No noise

# %%
U, latent_features, node_features = sub_noisy_feature_generator(group_label, num_features=40, num_latent_features=8, std=0.0, standard_basis=False)

# %% [markdown]
# ### LR loss

# %%
l3s = np.float32([1,5,10,20,50,100,500,1000])
num3 = len(l3s)
num = num3
flag = 1
f = plt.figure(figsize=(10,4))
for i in range(num3):
    ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
    lr = LR_Estimator(l3=l3s[i], method='cp', solver='SCS')
    lr.fit(node_features, maxiter=1000)
    lr.heatplot(xticklabels=False, yticklabels=False, cbar=True)
    ax0.set_title('l3:'+str(int(np.round(l3s[i]))))
    flag = flag+1
del l3s

# %% [markdown]
# ### ss_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del sse

# %% [markdown]
# ### as_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# ### aa_EL_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# ## Noise std=0.5

# %%
U, latent_features, node_features = sub_noisy_feature_generator(group_label, num_features=40, num_latent_features=8, std=0.5, standard_basis=False)

# %% [markdown]
# ### LR loss

# %%
l3s = np.float32([1,5,10,20,50,100,500,1000])
num3 = len(l3s)
num = num3
flag = 1
f = plt.figure(figsize=(10,4))
for i in range(num3):
    ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
    lr = LR_Estimator(l3=l3s[i], method='cp', solver='SCS')
    lr.fit(node_features, maxiter=1000)
    lr.heatplot(xticklabels=False, yticklabels=False, cbar=True)
    ax0.set_title('l3:'+str(int(np.round(l3s[i]))))
    flag = flag+1
del l3s

# %% [markdown]
# ### ss_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del sse

# %% [markdown]
# ### as_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# ### aa_EL_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# ## Noise std=1

# %%
U, latent_features, node_features = sub_noisy_feature_generator(group_label, num_features=40, num_latent_features=8, std=1.0, standard_basis=False)

# %% [markdown]
# ### LR loss

# %%
l3s = np.float32([1,5,10,20,50,100,500,1000])
num3 = len(l3s)
num = num3
flag = 1
f = plt.figure(figsize=(10,4))
for i in range(num3):
    ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
    lr = LR_Estimator(l3=l3s[i], method='cp', solver='SCS')
    lr.fit(node_features, maxiter=1000)
    lr.heatplot(xticklabels=False, yticklabels=False, cbar=True)
    ax0.set_title('l3:'+str(int(np.round(l3s[i]))))
    flag = flag+1
del l3s

# %% [markdown]
# ### ss_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            sse = ss_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            sse.fit(node_features, maxiter=1000)
            sse.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del sse

# %% [markdown]
# ### as_El_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            ase = as_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            ase.fit(node_features, maxiter=1000)
            ase.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del ase

# %% [markdown]
# ### aa_EL_Estimator

# %% [markdown]
# #### Lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

# %% [markdown]
# #### Normalized lap matrix

# %%
l1s = np.float32([0,1,10,50])
l2s = np.float32([0,1,10,50])
l3s = np.float32([0,1,10,50])
num1 = len(l1s)
num2 = len(l2s)
num3 = len(l3s)
num = num1 * num2 * num3
flag = 1
f = plt.figure(figsize=(10,32))
for i in range(num1):
    for j in range(num2):
        for k in range(num3):
            ax0 = f.add_subplot(np.int0(np.ceil(num/4)), 4, flag)
            aae = aa_El_Estimator(l1=l1s[i], l2=l2s[j], l3=l3s[k], Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
            aae.fit(node_features, maxiter=1000)
            aae.heatplot(xticklabels=False, yticklabels=False, cbar=True)
            ax0.set_title('l1:'+str(int(l1s[i]))+', '+'l2:'+str(int(l2s[j]))+', '+'l3:'+str(int(np.round(l3s[k]))))
            flag = flag+1
del l1s
del l2s
del l3s
del aae

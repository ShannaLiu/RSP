# %%
import sys
sys.path.append('/Users/liushuhan/Documents/AL_GNN/Experiments/RSP/Sythentic_graph')
sys.path.append('../')

from loss import *
from solver import *
from Generator import *

import matplotlib.pyplot as plt
import networkx as nx
import seaborn as sb

# %% [markdown]
# More noisy, stronger restriction is needed

# %% [markdown]
# l1 avoid diagonal, distribute evenly
# l2 same effect when l1 is not large enough

# %% [markdown]
# ### n = 30, p =50

# %% [markdown]
# ####  lap loss

# %%
list_shapes = ['nx.complete_graph'] * 6
list_shapes_args = [[5]] * 6
graph_type = 'nx.connected_watts_strogatz_graph'
graph_args = [6, 2, 0.4]
G, Gg, group_label, shape_label, shape_dist = synthetic_graph_generator(list_shapes, list_shapes_args, graph_type, graph_args, \
    plot=True, plot_color='group_label', savefig=False, root=None, figname=None)
node_features, group_mean = synthetic_feature_generator(group_label, num_features=50, std=1.5, save=False, root=False) 
node_features = node_features.numpy()
group_mean = group_mean.numpy()
L = np.float32(nx.laplacian_matrix(G).todense())
Gamma = np.float32(nx.incidence_matrix(G).todense().T) # E * N
for i in range(Gamma.shape[0]):
    for j in range(Gamma.shape[1]):
        if Gamma[i,j] !=0:
            Gamma[i,j] = - Gamma[i,j]
            break
# Out:
# /Users/liushuhan/Documents/AL_GNN/Experiments/RSP/Sythentic_graph/Generator.py:78: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   node_mean = torch.tensor(group_mean[group_label[i],])

# %%
# the optimal W when there is no constraint
l2s = np.float32([0, 10, 50, 100])
num = len(l2s)

f = plt.figure(figsize=(12,8))
for i in range(num):
    ax0 = f.add_subplot(eval('22'+str(i+1)))
    W = lap_sylvester_solver(X=node_features, L=L, l2=l2s[i])
    sb.heatmap(W, cmap='rainbow', center=0)
    loss = recon_loss(X=node_features, W=W).value + compute_lap_penalty(L=L, W=W, l2=l2s[i])
    ax0.set_title('lambda2='+str(l2s[i])+' '+'tot_loss='+str(loss))

# %% [markdown]
# #### elastic loss

# %%
# the optimal W when there is no constraint
l1s = np.float32([1, 10, 50])
l2s = np.float32([1, 10, 50])
num1 = len(l1s)
num2 = len(l2s)

f = plt.figure(figsize=(15,12))
for i in range(num1):
    for j in range(num2):
        ax0 = f.add_subplot(eval('33'+str(i*3+j+1)))
        ax0.set_axis_off
        W = elast_cp_solver(X=node_features, Gamma=Gamma, l1=l1s[i], l2=l2s[j], maxiter=50)
        sb.heatmap(W, cmap='rainbow', center=0)
        loss = recon_loss(X=node_features, W=W).value + ee_penalty(Gamma, W, l1=l1s[i], l2=l2s[j]).value
        ax0.set_title('lambda1='+str(l1s[i])+' '+'lambda2='+str(l2s[j])+'loss'+str(np.round(loss, 2)))
# Out:
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# /var/folders/v7/6y4d148j17v1f9cfgqn0t_ym0000gn/T/ipykernel_58400/714275371.py in <module>
#      10         ax0 = f.add_subplot(eval('33'+str(i*3+j+1)))
#      11         ax0.set_axis_off
# ---> 12         W = elast_cp_solver(X=node_features, Gamma=Gamma, l1=l1s[i], l2=l2s[j], maxiter=50)
#      13         sb.heatmap(W, cmap='rainbow', center=0)
#      14         loss = recon_loss(X=node_features, W=W).value + ee_penalty(Gamma, W, l1=l1s[i], l2=l2s[j]).value
#
# ~/Documents/AL_GNN/Experiments/RSP/Select_cluster/Ex/../solver.py in elast_cp_solver(X, Gamma, l1, l2, maxiter)
#       8     W = cp.Variable((n,n))
#       9     prob = cp.Problem(cp.Minimize( recon_loss(X, W) + ee_penalty(Gamma, W, l1, l2) ))
# ---> 10     prob.solve(max_iters=maxiter)
#      11     return W.value
#      12
#
# ~/opt/anaconda3/lib/python3.9/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     479         else:
#     480             solve_func = Problem._solve
# --> 481         return solve_func(self, *args, **kwargs)
#     482
#     483     @classmethod
#
# ~/opt/anaconda3/lib/python3.9/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, **kwargs)
#    1018         end = time.time()
#    1019         self._solve_time = end - start
# -> 1020         self.unpack_results(solution, solving_chain, inverse_data)
#    1021         if verbose:
#    1022             print(_FOOTER)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/cvxpy/problems/problem.py in unpack_results(self, solution, chain, inverse_data)
#    1343             warnings.warn(INF_OR_UNB_MESSAGE)
#    1344         if solution.status in s.ERROR:
# -> 1345             raise error.SolverError(
#    1346                     "Solver '%s' failed. " % chain.solver.name() +
#    1347                     "Try another solver, or solve with verbose=True for more "
#
# SolverError: Solver 'ECOS' failed. Try another solver, or solve with verbose=True for more information.

# %% [markdown]
# #### sparse loss

# %%
# the optimal W when there is no constraint
l1s = np.float32([1, 10, 20])
l2s = np.float32([1, 10, 20])
num1 = len(l1s)
num2 = len(l2s)

f = plt.figure(figsize=(15,12))
for i in range(num1):
    for j in range(num2):
        ax0 = f.add_subplot(eval('33'+str(i*3+j+1)))
        ax0.set_axis_off
        W = sparsel2_cp_solver(X=node_features, Gamma=Gamma, l1=l1s[i], l2=l2s[j], maxiter=50)
        sb.heatmap(W, cmap='rainbow', center=0)
        loss = recon_loss(X=node_features, W=W).value + sparse_lap(Gamma, W, l1=l1s[i], l2=l2s[j]).value
        ax0.set_title('lambda1='+str(l1s[i])+' '+'lambda2='+str(l2s[j]))

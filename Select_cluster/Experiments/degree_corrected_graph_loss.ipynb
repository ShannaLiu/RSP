# %% [markdown]
# **This file is for exploring the role of graph structure when using different graph losses**

# %%
sys.path.append('/Users/liushuhan/Documents/AL_GNN/Experiments/RSP/Sythentic_graph')
sys.path.append('../')
from Generator import *
from util import *
from loss import *
from Estimator import *
from cluster import *
import matplotlib.pyplot as plt

# %% [markdown]
# ### Star graph

# %% [markdown]
# #### Unnormalized Lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.star_graph(10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=8, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.star_graph(10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=8, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=20, l2=20, l3=20, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=20, l2=20, l3=20, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=20, l2=20, l3=20, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized Lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.star_graph(10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=8, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Tree graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
# Balanced tree
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.balanced_tree(r=3, h=2, create_using=None) # r: number of children, h: height of tree
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
# Balanced tree
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.balanced_tree(r=3, h=2, create_using=None) # r: number of children, h: height of tree
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Barbell Graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.barbell_graph(m1=4, m2=3)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.barbell_graph(m1=4, m2=3)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Complete graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.complete_graph(10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.complete_graph(10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Cycle graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.cycle_graph(n=10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.cycle_graph(n=10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Path graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
# path graph
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.path_graph(n=8)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
# path graph
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.path_graph(n=8)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Wheel graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.wheel_graph(n=10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.wheel_graph(n=10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Diamond graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.diamond_graph()
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.diamond_graph()
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### House graph

# %% [markdown]
# #### Unnormalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.house_graph()
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=False)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %% [markdown]
# #### Normalized lap matrix

# %%
f = plt.figure(figsize=(20,4))
ax0 = f.add_subplot(1, 4, 1)
G = nx.house_graph()
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# symmetric-symmetric elastic net
sse = ss_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
sse.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 4, 2)
sse.heatplot()
ax0.set_title('symmetric-symmetric elastic net')
# asmmetric-symmetric elastic net
ase = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
ase.fit(node_features, maxiter=500)
ax1 = f.add_subplot(1, 4, 3)
ase.heatplot()
ax1.set_title('asmmetric-symmetric elastic net')
# asmmetric-asymmetric elastic net
aae = aa_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
aae.fit(node_features, maxiter=500)
ax2 = f.add_subplot(1, 4, 4)
aae.heatplot()
ax2.set_title('asmmetric-asymmetric elastic net')
# Out:
# Text(0.5, 1.0, 'asmmetric-asymmetric elastic net')

# %%
sys.path.append('/Users/liushuhan/Documents/AL_GNN/Experiments/RSP/Sythentic_graph')
sys.path.append('../')
from Generator import *
from util import *
from loss import *
from Estimator import *
from cluster import *
import matplotlib.pyplot as plt

# %% [markdown]
# ### Star graph

# %%
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.star_graph(10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=8, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used
# /Users/liushuhan/opt/anaconda3/lib/python3.9/site-packages/cvxpy/problems/problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=10, l2=10, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
see = LR_Estimator(l3=0, method='cp', solver='SCS')
see.fit(X, maxiter=500)
see.heatplot()

# %% [markdown]
# #### Tree graph

# %%
# Balanced tree
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.balanced_tree(r=3, h=2, create_using=None) # r: number of children, h: height of tree
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### Barbell Graph

# %%
# barbell_graph (two complete graph connected by a path)
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.barbell_graph(m1=4, m2=3)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### Complete graph

# %%
# topological structure
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.complete_graph(9)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
# nonsymmetric elastic net
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### Cycle graph

# %%
# cycle graph
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.cycle_graph(n=10)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### Path graph

# %%
# path graph
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.path_graph(n=8)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### Wheel graph

# %%
# wheel graph
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.wheel_graph(n=9)
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### Diamond graph

# %%
# diamond graph
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.G = nx.diamond_graph()
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %% [markdown]
# #### House graph

# %%
# house graph
f = plt.figure(figsize=(10,4))
ax0 = f.add_subplot(1, 2, 1)
G = nx.house_graph()
nx.draw(G, with_labels=True)
L, D, Gamma = graph_to_mat(G)
group_label = [0] * G.number_of_nodes()
U, latent_features, node_features = sub_clean_feature_generator(group_label, num_features=20, num_latent_features=10, standard_basis=False)
# nonsymmetric elastic net
see = as_El_Estimator(l1=10000, l2=10000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(node_features, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
X = clean_feature_generator(group_label, num_features=20)
see = as_El_Estimator(l1=1000, l2=1000, l3=0, Gamma=Gamma, D=D, method='cp', solver='SCS', deg_crct=True)
see.fit(X, maxiter=500)
ax0 = f.add_subplot(1, 2, 2)
see.heatplot()
# Out:
# Degree corrected incidence matrix is used

# %%
import torch
import numpy as np
from op_const_dist import *
import matplotlib.pyplot as plt

# %%
X = torch.randn(100,2)
T = torch.randn(100,100).abs()

# %%
# W, loss_rec, _, _, _, _, _, _ = op_const_dist(X, T, r=3, lamda1=1, epsilon=1e-3, ratio=0.5, max_iter=100, plot=True, training_mask=None)

# %%
W, _, _, _, _, _, _, _ = op_const_dist(X, T, r=100, lamda1=1, epsilon=1e-8, ratio=0.1, max_iter=300, plot=True, training_mask=None)

# %%
import torch
import numpy as np
from op_const_dist import *
import matplotlib.pyplot as plt

# %%
X = torch.randn(1000,2)
T = torch.randn(1000,1000).abs()

# %%
W, loss_rec, _, _, _, _, _, _ = op_const_dist(X, T, r=3, epsilon=1e-3, ratio=0.5, max_iter=100, plot=True, training_mask=None)

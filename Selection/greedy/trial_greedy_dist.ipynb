# %%
import torch
import numpy as np
from greedy_dist import *
import matplotlib.pyplot as plt

# %%
X = torch.randn(100,10)
T = torch.randn(100,100).abs()

# %%
W = greedy_dist(X, T, r=50, lambda1=1, plot=True)
